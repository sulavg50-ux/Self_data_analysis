# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa=pd.read_csv("fifa.csv")

# %%
fifa
# Out:
#        Unnamed: 0  sofifa_id  \
# 0               0     158023
# 1               1      20801
# 2               2       9014
# 3               3      41236
# 4               4     167495
# ...           ...        ...
# 16150       16150     220806
# 16151       16151     225509
# 16152       16152     217591
# 16153       16153     222947
# 16154       16154     201197
#
#                                               player_url         short_name  \
# 0      https://sofifa.com/player/158023/lionel-messi/...           L. Messi
# 1      https://sofifa.com/player/20801/c-ronaldo-dos-...  Cristiano Ronaldo
# 2      https://sofifa.com/player/9014/arjen-robben/15...          A. Robben
# 3      https://sofifa.com/player/41236/zlatan-ibrahim...     Z. Ibrahimović
# 4      https://sofifa.com/player/167495/manuel-neuer/...           M. Neuer
# ...                                                  ...                ...
# ...

# %%
fifa.head()
# Out:
#    Unnamed: 0  sofifa_id                                         player_url  \
# 0           0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1           1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3           3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4           4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
#
# ...

# %%
#data cleaning
#remove duplicate rows
fifa.drop_duplicates(inplace=True)

# %% [raw]
# print(fifa.isnull().sum())

# %%
for col in fifa.columns:
    print(col)
# Out:
# Unnamed: 0
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club_name
# league_name
# league_rank
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# ...

# %%
fifa.shape
# Out:
# (16155, 81)

# %%
#calculate total cells
161555*81
# Out:
# 13085955

# %%
fifa['nationality'].value_counts()
# Out:
# nationality
# England        1627
# Spain          1051
# France          958
# Argentina       867
# Italy           795
#                ...
# Kyrgyzstan        1
# Fiji              1
# Saint Lucia       1
# Montserrat        1
# Indonesia         1
# Name: count, Length: 149, dtype: int64

# %%
#top 10 ota players that has high num players
fifa['nationality'].value_counts()[0:10].keys()
# Out:
# Index(['England', 'Spain', 'France', 'Argentina', 'Italy', 'Germany',
#        'Colombia', 'Republic of Ireland', 'Netherlands', 'Brazil'],
#       dtype='object', name='nationality')

# %%
fifa['nationality'].value_counts()[0:10]
# Out:
# nationality
# England                1627
# Spain                  1051
# France                  958
# Argentina               867
# Italy                   795
# Germany                 701
# Colombia                543
# Republic of Ireland     460
# Netherlands             419
# Brazil                  416
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.bar(fifa['nationality'].value_counts()[0:5].keys(),
        fifa['nationality'].value_counts()[0:5],color='grey'
       )
plt.show()

# %%
player_salary=fifa[['short_name','wage_eur']]
player_salary
# Out:
#               short_name  wage_eur
# 0               L. Messi    550000
# 1      Cristiano Ronaldo    375000
# 2              A. Robben    275000
# 3         Z. Ibrahimović    275000
# 4               M. Neuer    300000
# ...                  ...       ...
# 16150          E. Redman      2000
# 16151         A. Collins      2000
# 16152           P. Żemło      2000
# 16153          T. Davies      2000
# 16154         P. Tisdale      2000
#
# [16155 rows x 2 columns]

# %%
#top 5 player that has high salary
player_salary=player_salary.sort_values(by=['wage_eur'],ascending=False)
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    550000
# 1  Cristiano Ronaldo    375000
# 4           M. Neuer    300000
# 5          L. Suárez    300000
# 2          A. Robben    275000

# %%
short_name=fifa[['long_name','short_name']]
short_name
# Out:
#                                  long_name         short_name
# 0           Lionel Andrés Messi Cuccittini           L. Messi
# 1      Cristiano Ronaldo dos Santos Aveiro  Cristiano Ronaldo
# 2                             Arjen Robben          A. Robben
# 3                       Zlatan Ibrahimović     Z. Ibrahimović
# 4                             Manuel Neuer           M. Neuer
# ...                                    ...                ...
# 16150                         Ellis Redman          E. Redman
# 16151                        Aaron Collins         A. Collins
# 16152                          Piotr Żemło           P. Żemło
# 16153                           Tom Davies          T. Davies
# 16154                         Paul Tisdale         P. Tisdale
#
# [16155 rows x 2 columns]

# %%
plt.figure(figsize=(6,6))
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5],color=('red','blue','green','pink'))
# Out:
# <BarContainer object of 5 artists>

# %%
#nationality that has germany
fifa['nationality']=="Germany"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 16150    False
# 16151    False
# 16152    False
# 16153    False
# 16154    False
# Name: nationality, Length: 16155, dtype: bool

# %%
ger=fifa[fifa['nationality']=="Germany"]
ger.head()
# Out:
#     Unnamed: 0  sofifa_id                                         player_url  \
# 4            4     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 9            9     121944  https://sofifa.com/player/121944/bastian-schwe...
# 14          14     121939  https://sofifa.com/player/121939/philipp-lahm/...
# 22          22     178603  https://sofifa.com/player/178603/mats-hummels/...
# 24          24     188350  https://sofifa.com/player/188350/marco-reus/15...
#
#            short_name               long_name  age         dob  height_cm  \
# 4            M. Neuer            Manuel Neuer   28  1986-03-27        193
# 9   B. Schweinsteiger  Bastian Schweinsteiger   29  1984-08-01        183
# 14            P. Lahm            Philipp Lahm   30  1983-11-11        170
# 22         M. Hummels            Mats Hummels   25  1988-12-16        192
# 24            M. Reus              Marco Reus   25  1989-05-31        181
#
# ...

# %%
#top 5 playyer acc to height
ger.sort_values(by=['height_cm'],ascending=False)
ger.head()
# Out:
#     Unnamed: 0  sofifa_id                                         player_url  \
# 4            4     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 9            9     121944  https://sofifa.com/player/121944/bastian-schwe...
# 14          14     121939  https://sofifa.com/player/121939/philipp-lahm/...
# 22          22     178603  https://sofifa.com/player/178603/mats-hummels/...
# 24          24     188350  https://sofifa.com/player/188350/marco-reus/15...
#
#            short_name               long_name  age         dob  height_cm  \
# 4            M. Neuer            Manuel Neuer   28  1986-03-27        193
# 9   B. Schweinsteiger  Bastian Schweinsteiger   29  1984-08-01        183
# 14            P. Lahm            Philipp Lahm   30  1983-11-11        170
# 22         M. Hummels            Mats Hummels   25  1988-12-16        192
# 24            M. Reus              Marco Reus   25  1989-05-31        181
#
# ...

# %%
ger.sort_values(by=['weight_kg'],ascending=False)
ger.head()
# Out:
#     Unnamed: 0  sofifa_id                                         player_url  \
# 4            4     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 9            9     121944  https://sofifa.com/player/121944/bastian-schwe...
# 14          14     121939  https://sofifa.com/player/121939/philipp-lahm/...
# 22          22     178603  https://sofifa.com/player/178603/mats-hummels/...
# 24          24     188350  https://sofifa.com/player/188350/marco-reus/15...
#
#            short_name               long_name  age         dob  height_cm  \
# 4            M. Neuer            Manuel Neuer   28  1986-03-27        193
# 9   B. Schweinsteiger  Bastian Schweinsteiger   29  1984-08-01        183
# 14            P. Lahm            Philipp Lahm   30  1983-11-11        170
# 22         M. Hummels            Mats Hummels   25  1988-12-16        192
# 24            M. Reus              Marco Reus   25  1989-05-31        181
#
# ...

# %%
#player shooting
shoot=fifa[['short_name','shooting']]

# %%
shoot.head()
# Out:
#           short_name  shooting
# 0           L. Messi      89.0
# 1  Cristiano Ronaldo      93.0
# 2          A. Robben      86.0
# 3     Z. Ibrahimović      91.0
# 4           M. Neuer       NaN

# %%
#top 5 plyer s=that has highest shooting
shoot=shoot.sort_values(by=['shooting'],ascending=False)
shoot.head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 3       Z. Ibrahimović      91.0
# 8        R. van Persie      90.0
# 0             L. Messi      89.0
# 634        L. Podolski      87.0

# %%
#defending
defend=fifa[['short_name','defending']]
defend.head()
# Out:
#           short_name  defending
# 0           L. Messi       27.0
# 1  Cristiano Ronaldo       32.0
# 2          A. Robben       32.0
# 3     Z. Ibrahimović       34.0
# 4           M. Neuer        NaN

# %%
#top 5 defender
defend=defend.sort_values(by=['defending'],ascending=False)
defend.head()
# Out:
#         short_name  defending
# 16    Thiago Silva       90.0
# 22      M. Hummels       88.0
# 50      M. Benatia       88.0
# 31      V. Kompany       87.0
# 80  P. Mertesacker       87.0

# %%
plt.figure(figsize=(6,6))
plt.bar(defend['defending'].value_counts().head(5),
        defend['defending'].value_counts().head(5))
plt.title("Top 5 Defending Values")
plt.xlabel("Defending Rating")
plt.ylabel("Count")
plt.show()

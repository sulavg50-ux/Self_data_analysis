# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
sales=pd.read_csv('sales.csv')
sales.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
sales.drop_duplicates(inplace=True)

# %%
print(sales.isnull().sum())
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %%
sales.head(5)
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
#Total Revenue
sales['Revenue'].sum()
# Out:
# np.int64(84826772)

# %%
#average Revenue
sales['Revenue'].mean()
# Out:
# np.float64(757.1385269020672)

# %%
#max revenue
sales['Revenue'].max()
# Out:
# 58074

# %%
sales['Revenue'].min()
# Out:
# 2

# %%
sales=sales[['Revenue','Year']]
sales
# Out:
#         Revenue  Year
# 0           950  2013
# 1           950  2015
# 2          2401  2014
# 3          2088  2016
# 4           418  2014
# ...         ...   ...
# 113031      184  2016
# 113032     1183  2014
# 113033     1183  2016
# 113034     1260  2014
# 113035     1207  2016
#
# [112036 rows x 2 columns]

# %%
#top 5 revenue
sales=sales.sort_values(by=['Revenue'],ascending=False)
sales.head(5)
# Out:
#         Revenue  Year
# 112073    58074  2015
# 112072    54069  2013
# 71129     14312  2011
# 70601     14169  2011
# 70699     14169  2011

# %%
print(sales.columns)
# Out:
# Index(['Revenue', 'Year'], dtype='object')

# %%
import pandas as pd

sales = pd.read_csv('sales.csv')

print(sales.columns.tolist())
# Out:
# ['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group', 'Customer_Gender', 'Country', 'State', 'Product_Category', 'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price', 'Profit', 'Cost', 'Revenue']

# %%
sales=sales[['Revenue','Month','Year']]

# %%
sales
# Out:
#         Revenue     Month  Year
# 0           950  November  2013
# 1           950  November  2015
# 2          2401     March  2014
# 3          2088     March  2016
# 4           418       May  2014
# ...         ...       ...   ...
# 113031      184     April  2016
# 113032     1183     April  2014
# 113033     1183     April  2016
# 113034     1260     March  2014
# 113035     1207     March  2016
#
# [113036 rows x 3 columns]

# %%
#top5 acc to month and year
sales=sales.sort_values(by=['Revenue'],ascending=False)
sales.head(10)
# Out:
#         Revenue      Month  Year
# 112073    58074       July  2015
# 112072    54069       July  2013
# 71129     14312       July  2011
# 70307     14169      April  2011
# 70601     14169  September  2011
# 70699     14169       July  2011
# 70597     14169        May  2011
# 70745     14169   February  2011
# 59919     14169      March  2011
# 68671     14169       July  2011

# %%
s1=sales.head(30)
plt.figure(figsize=(6,6))
plt.bar(s1['Month'],s1['Revenue'])
plt.xticks(rotation=45)
plt.show()

# %%
sales=pd.read_csv('Sales.csv')
sales=sales[['Revenue','Country']]
sales
# Out:
#         Revenue         Country
# 0           950          Canada
# 1           950          Canada
# 2          2401       Australia
# 3          2088       Australia
# 4           418       Australia
# ...         ...             ...
# 113031      184  United Kingdom
# 113032     1183       Australia
# 113033     1183       Australia
# 113034     1260          France
# 113035     1207          France
#
# [113036 rows x 2 columns]

# %%
sales=sales.sort_values(by=['Revenue'],ascending=False)
sales.head(5)
# Out:
#         Revenue    Country
# 112073    58074  Australia
# 112072    54069  Australia
# 71129     14312     Canada
# 70307     14169     Canada
# 70601     14169     Canada

# %%
sales=pd.read_csv('Sales.csv')
sales
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
#product by quantity sold
product=sales[['Product','Order_Quantity']]
product=product.sort_values(by=['Order_Quantity'],ascending=False)
product.head(5)
# Out:
#                               Product  Order_Quantity
# 26099           Fender Set - Mountain              32
# 29583           Half-Finger Gloves, M              32
# 16386           Water Bottle - 30 oz.              32
# 48231  Short-Sleeve Classic Jersey, M              32
# 81899                    ML Road Tire              32

# %%
p1 = product.head(5)

plt.figure(figsize=(6,6))
plt.pie(p1['Order_Quantity'],
        labels=p1['Product'],
        autopct='%1.1f%%')

plt.title("Top 5 Products by Order Quantity")
plt.show()

# %%
sales=pd.read_csv('Sales.csv')
sales
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
#total profit
sales['Profit'].sum()
# Out:
# np.int64(32221100)

# %%
#average profit
sales['Profit'].mean()
# Out:
# np.float64(285.0516649562971)

# %%
#profit by year
s1=sales[['Profit','Year']]
s1
# Out:
#         Profit  Year
# 0          590  2013
# 1          590  2015
# 2         1366  2014
# 3         1188  2016
# 4          238  2014
# ...        ...   ...
# 113031     112  2016
# 113032     655  2014
# 113033     655  2016
# 113034     684  2014
# 113035     655  2016
#
# [113036 rows x 2 columns]

# %%
#top 5 profit by year
s2=s1.sort_values(by=['Profit'],ascending=False)
s2.head(5)
# Out:
#         Profit  Year
# 112073   15096  2015
# 112072   14055  2013
# 57273     5638  2011
# 71129     5628  2011
# 59919     5485  2011

# %%
s3=s2.head(5)
plt.figure(figsize=(6,6))

plt.pie(s3['Profit'],
        labels=s3['Year'],
        autopct='%1.1f%%')

plt.title('Profit by Year')
plt.show()

# %%
#profit by state
p1=sales[['Profit','State']]
p1
# Out:
#         Profit             State
# 0          590  British Columbia
# 1          590  British Columbia
# 2         1366   New South Wales
# 3         1188   New South Wales
# 4          238   New South Wales
# ...        ...               ...
# 113031     112           England
# 113032     655        Queensland
# 113033     655        Queensland
# 113034     684     Seine (Paris)
# 113035     655     Seine (Paris)
#
# [113036 rows x 2 columns]

# %%
p1.sort_values(by=['Profit'],ascending=False)
p1.head(5)
# Out:
#    Profit             State
# 0     590  British Columbia
# 1     590  British Columbia
# 2    1366   New South Wales
# 3    1188   New South Wales
# 4     238   New South Wales

# %%
#profit by product category
p2=sales[['Profit','Product_Category']]
p2=p2.sort_values(by=['Product_Category'],ascending=False)
p2.head(10)
# Out:
#         Profit Product_Category
# 113035     655         Clothing
# 21272       14         Clothing
# 43294       87         Clothing
# 21281        7         Clothing
# 21280        5         Clothing
# 21279       43         Clothing
# 21278       41         Clothing
# 21277       20         Clothing
# 21276       16         Clothing
# 21275       11         Clothing

# %%
#Top 10 Products by Profit
p2=p2.sort_values(by=['Profit'],ascending=False)
p2.head(10)
# Out:
#         Profit Product_Category
# 112073   15096         Clothing
# 112072   14055         Clothing
# 57273     5638            Bikes
# 71129     5628            Bikes
# 68671     5485            Bikes
# 70597     5485            Bikes
# 70307     5485            Bikes
# 70601     5485            Bikes
# 59919     5485            Bikes
# 70699     5485            Bikes

# %%
#SALES PART
#Total order quantity
sales['Order_Quantity'].sum()
# Out:
# np.int64(1345316)

# %%
#average order quantity
sales['Order_Quantity'].mean()
# Out:
# np.float64(11.901659648253654)

# %%
#Order_Quantity by year
s4=sales[['Order_Quantity','Year']]
s4
# Out:
#         Order_Quantity  Year
# 0                    8  2013
# 1                    8  2015
# 2                   23  2014
# 3                   20  2016
# 4                    4  2014
# ...                ...   ...
# 113031               3  2016
# 113032              22  2014
# 113033              22  2016
# 113034              24  2014
# 113035              23  2016
#
# [113036 rows x 2 columns]

# %%
s4=s4.sort_values(by=['Order_Quantity'],ascending=False)
s4.head(20)
# Out:
#         Order_Quantity  Year
# 26099               32  2015
# 29583               32  2015
# 16386               32  2015
# 48231               32  2015
# 81899               32  2015
# 7386                32  2016
# 7389                32  2016
# 29655               32  2016
# 102565              32  2016
# 3594                32  2015
# 101131              32  2016
# 42385               32  2015
# 25041               32  2015
# 75359               32  2015
# 86650               32  2016
# 3526                32  2016
# 16634               32  2015
# 86713               32  2016
# 93069               32  2016
# 97963               32  2015

# %%
#top selling products
s5=sales[['Product']]
s5
# Out:
#                     Product
# 0       Hitch Rack - 4-Bike
# 1       Hitch Rack - 4-Bike
# 2       Hitch Rack - 4-Bike
# 3       Hitch Rack - 4-Bike
# 4       Hitch Rack - 4-Bike
# ...                     ...
# 113031      Classic Vest, S
# 113032      Classic Vest, M
# 113033      Classic Vest, M
# 113034      Classic Vest, L
# 113035      Classic Vest, L
#
# [113036 rows x 1 columns]

# %%
s5=s5.sort_values(by=['Product'],ascending=False)
s5.head()
# Out:
#                           Product
# 72756  Women's Mountain Shorts, S
# 71679  Women's Mountain Shorts, S
# 71685  Women's Mountain Shorts, S
# 71684  Women's Mountain Shorts, S
# 71683  Women's Mountain Shorts, S

# %%
#product analysis
#most expensive product
s5=sales[['Product','Cost']]
s5
# Out:
#                     Product  Cost
# 0       Hitch Rack - 4-Bike   360
# 1       Hitch Rack - 4-Bike   360
# 2       Hitch Rack - 4-Bike  1035
# 3       Hitch Rack - 4-Bike   900
# 4       Hitch Rack - 4-Bike   180
# ...                     ...   ...
# 113031      Classic Vest, S    72
# 113032      Classic Vest, M   528
# 113033      Classic Vest, M   528
# 113034      Classic Vest, L   576
# 113035      Classic Vest, L   552
#
# [113036 rows x 2 columns]

# %%
s5=s5.sort_values(by=['Cost'],ascending=False)
s5.head(1)
# Out:
#                         Product   Cost
# 112073  Touring-1000 Yellow, 50  42978

# %%
#most expensive product
sales.loc[sales['Cost'].idxmax(), ['Product', 'Cost']]
# Out:
# Product    Touring-1000 Yellow, 50
# Cost                         42978
# Name: 112073, dtype: object

# %%
#cheapest product
s5=s5.sort_values(by=['Cost'],ascending=True)
s5.head(1)
# Out:
#                    Product  Cost
# 78774  Patch Kit/8 Patches     1

# %%
#most cheapest product
sales.loc[sales['Cost'].idxmin(), ['Product', 'Cost']]
# Out:
# Product    Patch Kit/8 Patches
# Cost                         1
# Name: 74663, dtype: object

# %%
#top products by revenue
top=sales[['Product','Revenue']]
top
# Out:
#                     Product  Revenue
# 0       Hitch Rack - 4-Bike      950
# 1       Hitch Rack - 4-Bike      950
# 2       Hitch Rack - 4-Bike     2401
# 3       Hitch Rack - 4-Bike     2088
# 4       Hitch Rack - 4-Bike      418
# ...                     ...      ...
# 113031      Classic Vest, S      184
# 113032      Classic Vest, M     1183
# 113033      Classic Vest, M     1183
# 113034      Classic Vest, L     1260
# 113035      Classic Vest, L     1207
#
# [113036 rows x 2 columns]

# %%
#another version
sales.groupby('Product')['Revenue'].sum().sort_values(ascending=False).head()
# Out:
# Product
# Road-150 Red, 62           3829416
# Mountain-200 Black, 38     3366248
# Road-150 Red, 52           3180840
# Road-150 Red, 56           3158805
# Mountain-200 Silver, 42    3081078
# Name: Revenue, dtype: int64

# %%
sales.groupby('Product')['Profit'].sum().sort_values(ascending=False).head()
# Out:
# Product
# Mountain-200 Black, 38     1310464
# Road-150 Red, 62           1243755
# Mountain-200 Silver, 42    1231452
# Sport-100 Helmet, Red      1191402
# Mountain-200 Silver, 38    1165560
# Name: Profit, dtype: int64

# %%
sales.groupby('Product')['Order_Quantity'].sum().sort_values(ascending=False).head()
# Out:
# Product
# Water Bottle - 30 oz.    164086
# Patch Kit/8 Patches      157583
# Mountain Tire Tube       102792
# AWC Logo Cap              67316
# Sport-100 Helmet, Red     63663
# Name: Order_Quantity, dtype: int64

# %%
sales=pd.read_csv('sales.csv')
sales
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
#order quantity by gender
gen=sales[['Order_Quantity','Customer_Gender']]
gen
# Out:
#         Order_Quantity Customer_Gender
# 0                    8               M
# 1                    8               M
# 2                   23               M
# 3                   20               M
# 4                    4               F
# ...                ...             ...
# 113031               3               M
# 113032              22               M
# 113033              22               M
# 113034              24               F
# 113035              23               F
#
# [113036 rows x 2 columns]

# %%
gender = sales.groupby('Customer_Gender')['Order_Quantity'].sum()

plt.figure(figsize=(6,6))
plt.bar(gender.index, gender.values)
plt.xlabel("Gender")
plt.ylabel("Total Order Quantity")
plt.show()

# %%
#Order Quantity by Country
s1=sales.groupby('Country')['Order_Quantity'].sum().sort_values(ascending=False)
s1
# Out:
# Country
# United States     477539
# Australia         263585
# Canada            192259
# United Kingdom    157218
# France            128995
# Germany           125720
# Name: Order_Quantity, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.bar(s1.index,s1.values)
plt.title('Order Quantity by Country')
plt.xticks(rotation=45)
plt.show()

# %%
#monthly revenue trend
mon=sales.groupby('Month')['Revenue'].sum()
plt.figure(figsize=(6,6))
plt.bar(mon.index,mon.values)
plt.title('Monthly Revenue Trend')
plt.xlabel('Month')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.show()

# %%
#Monthly Profit Trend
s4=sales.groupby('Month')['Profit'].sum().sort_values(ascending=False)
s4
# Out:
# Month
# December     3409712
# June         3383583
# May          3326937
# April        2864719
# March        2761866
# January      2618521
# February     2562322
# November     2388513
# October      2301312
# September    2249661
# August       2214204
# July         2139750
# Name: Profit, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.bar(s4.index,s4.values)
plt.xticks(rotation=45)
plt.show()

# %%
#revenue vs Profit
plt.figure(figsize=(6,6))

plt.scatter(sales['Revenue'], sales['Profit'])

plt.title('Revenue vs Profit')
plt.xlabel('Revenue')
plt.ylabel('Profit')

plt.show()

# %%
#Order Quantity vs Revenue
plt.figure(figsize=(6,6))
plt.plot(sales['Order_Quantity'],sales['Revenue'])
plt.title('Order Quantity vs Revenue')
plt.show()

# %%
#Customer Age vs Profit
plt.figure(figsize=(6,6))
plt.scatter(sales['Customer_Age'],sales['Profit'])
plt.title('Customer Age vs Profit')
plt.show()

# %%
corr=sales.corr(numeric_only=True)
corr
# Out:
#                      Day      Year  Customer_Age  Order_Quantity  Unit_Cost  \
# Day             1.000000 -0.007635     -0.014296       -0.002412   0.003133
# Year           -0.007635  1.000000      0.040994        0.123169  -0.217575
# Customer_Age   -0.014296  0.040994      1.000000        0.026887  -0.021374
# Order_Quantity -0.002412  0.123169      0.026887        1.000000  -0.515835
# Unit_Cost       0.003133 -0.217575     -0.021374       -0.515835   1.000000
# Unit_Price      0.003207 -0.213673     -0.020262       -0.515925   0.997894
# Profit          0.004623 -0.181525      0.004319       -0.238863   0.741020
# Cost            0.003329 -0.215604     -0.016013       -0.340382   0.829869
# Revenue         0.003853 -0.208673     -0.009326       -0.312895   0.817865
#
#                 Unit_Price    Profit      Cost   Revenue
# Day               0.003207  0.004623  0.003329  0.003853
# Year             -0.213673 -0.181525 -0.215604 -0.208673
# ...

# %%
import seaborn as sns
plt.figure(figsize=(8,6))

sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.9)

plt.title('Correlation Matrix')
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.boxplot(sales['Revenue'])
plt.title("Revenue Outliers")
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.boxplot(sales['Profit'])
plt.title("Profit Outliers")
plt.show()

# %%
plt.figure(figsize=(5,5))
plt.boxplot(sales['Customer_Age'])
plt.title("Customer Age Outliers")
plt.show()

# %%
s1=sales[['Revenue']]
s1.head()
# Out:
#    Revenue
# 0      950
# 1      950
# 2     2401
# 3     2088
# 4      418

# %%
s2=s1.head(10)
plt.figure(figsize=(6,5))

plt.hist(s2['Revenue'], edgecolor='black')

plt.title('Revenue Distribution')
plt.xlabel('Revenue')
plt.ylabel('Frequency')

plt.show()

# %%
sales
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
s9=sales.groupby('Product_Category')['Profit'].sum().sort_values(ascending=False)
plt.figure(figsize=(6,6))
plt.bar(s9.index,s9.values,color='grey')
plt.title('Profit by Product category')
plt.show()

# %%
#horizontal
s9=sales.groupby('Product_Category')['Profit'].sum().sort_values(ascending=False)
plt.figure(figsize=(6,6))
plt.barh(s9.index,s9.values,color='grey')
plt.title('Profit by Product category')
plt.show()

# %%
s10=sales.groupby('Month')['Revenue'].sum().sort_values(ascending=False)
s10
# Out:
# Month
# December     9086931
# June         9043008
# May          8836763
# April        7602750
# March        7347164
# January      7005895
# February     6834583
# November     6244298
# October      5995079
# September    5841885
# July         5721459
# August       5711193
# Name: Revenue, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.plot(s10.index,s10.values)
plt.title('Monthly revenue')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(6,6))

plt.scatter(sales['Revenue'], sales['Profit'], alpha=0.6)

plt.title('Revenue vs Profit')
plt.xlabel('Revenue')
plt.ylabel('Profit')

plt.show()

# %%
plt.figure(figsize=(6,6))
plt.boxplot(sales['Revenue'])
plt.show()

# %%
plt.figure(figsize=(6,5))

sns.violinplot(sales['Profit'])

plt.title('Profit Distribution')
plt.show()

# %%
# sum revenue by category
data = sales.groupby('Product_Category')['Revenue'].sum()

plt.figure(figsize=(6,6))
plt.pie(data.values,
        labels=data.index,
        autopct='%1.1f%%')

plt.title('Product Category Share')
plt.show()

# %%
sns.countplot(x='Customer_Gender', data=sales)

plt.title('Gender Count')
plt.show()

# %%
corr=sales.corr(numeric_only=True)
corr
# Out:
#                      Day      Year  Customer_Age  Order_Quantity  Unit_Cost  \
# Day             1.000000 -0.007635     -0.014296       -0.002412   0.003133
# Year           -0.007635  1.000000      0.040994        0.123169  -0.217575
# Customer_Age   -0.014296  0.040994      1.000000        0.026887  -0.021374
# Order_Quantity -0.002412  0.123169      0.026887        1.000000  -0.515835
# Unit_Cost       0.003133 -0.217575     -0.021374       -0.515835   1.000000
# Unit_Price      0.003207 -0.213673     -0.020262       -0.515925   0.997894
# Profit          0.004623 -0.181525      0.004319       -0.238863   0.741020
# Cost            0.003329 -0.215604     -0.016013       -0.340382   0.829869
# Revenue         0.003853 -0.208673     -0.009326       -0.312895   0.817865
#
#                 Unit_Price    Profit      Cost   Revenue
# Day               0.003207  0.004623  0.003329  0.003853
# Year             -0.213673 -0.181525 -0.215604 -0.208673
# ...

# %%
plt.figure(figsize=(13,10))
sns.heatmap(corr, annot=True, linewidth='0.9')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.pairplot(sales[['Revenue', 'Profit', 'Cost', 'Order_Quantity']])

plt.show()
